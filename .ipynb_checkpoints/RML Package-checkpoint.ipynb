# %% [markdown]
# # Relational Measurement Package
#
#
# ## Data Structure
#
#  * raw [2D array of raw values]
#  * network [array of dicts]
#   * messages [array of values by timeslice]
#   * entropies [array of entropies by timeslice]
#  * nodes [array of dicts]
#   * id [string]
#   * messages_sent [list of lists: [total value sent, dict of all ids sent]]
#   * messages_recieved [list of list: [total value received, dict of all ids received]]
#   * probabilities [array of dicts by timeslice]
#   * entropies [array of entropies by timeslice]
#
# ## Core Functions
#
#
#
# *input* (file)
#  - Pulls in data in CSV format of format:
#      _to_, _from_, _timestamp_, _value_ (optional)
#  - Stores it as an array of tuples called raw_data
#  - Stores values based on _value_ column or sets to 1
#  - calculates entropies and probabilities
#  - _returns null_
#
# *init* (timeslice_size, sc)
#  - timeslice_size: determines the size of each timeslice.
#  - sc: smoothing constant used to calculate probabilities
#  - sets constants
#  - _returns null_
#
# *timeslice* (raw)
#  - stores inputted data by timeslice
#
# *calculate_probabilities* (self)
#  - calculates probabilities for each timeslice
#
# *calculate_entropies* (self)
#  - calculates entropy values for each timeslice
#
# *display_entropy* (self, nodes(optional), timeslice_range(optional))
#  - shows a graph of entropy
#
# *display_graph* (self, timeslice, nodes(optional)
#  - shows a graph visualization of nodes at a given timeslice

# %%
from random import random
from math import log, ceil, floor
from pyvis import network as net
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline


class Relmeasure:
    #
    # Timeslice_size: Int = chunks of time used to divide messages for analysis in seconds.
    # Smoothing: Float = Value between 0 and 1 that defines how strongly recent messages shift the probability distribution of each node.
    # Data: Array of metadata about a series of messages = [[Sender, Recipient, Timestamp]]
    # 
    def __init__(self, timeslice_size, smoothing, data):
        self.timeslice_size = timeslice_size
        self.smoothing = smoothing
        self.raw = data
        self.network = {}
        self.nodes = []
        
    def entropy(self, probabilities):
        entropy = 0
        for k in probabilities.keys():
            p = probabilities[k]
            if (p > 0):
                entropy += p * log(p)
        return entropy
    
    def probabilities(self, node_val, total_val, num_nodes, last_probs):
        if total_val == 0:
            return last_probs
        return last_probs * (1 + self.smoothing*(node_val/total_val - 1/(num_nodes - 1)))
    
    def init_nodes(self):
        self.raw.sort(key=lambda node:node[2])
        num_slices = ceil((self.raw[-1][2] - self.raw[0][2])/self.timeslice_size) + 1
        self.min_time = self.raw[0][2]
        self.max_time = self.raw [-1][2]
        self.num_slices = num_slices
        ids = []
        template_dict = {}
        template1 = [[0, {}] for x in range(num_slices)]
        template2 = [0 for x in range(num_slices)]  
        self.network = {'msg_vals':template2.copy(), 'entropies':template2.copy()}
        
        ids = []
        for message in self.raw:
            if not (message[0] in ids):
                ids.append(message[0])
#             if not (message[1] in ids):
#                 ids.append(message[1])

        self.num_nodes = len(ids)
        
        template_dict = {}
        template_probs = {}
        for i in ids:
            template_probs[i] = float(1/self.num_nodes)
        
        template1 = [[0, template_dict.copy()] for x in range(num_slices)]
        template2 = [0 for x in range(num_slices)]
        template3 = [template_probs.copy() for y in range(num_slices)]
        
        for i in ids:
            self.nodes.append({'id':i, 'msg_sent':template1.copy(), 'msg_rcvd':template1.copy(), 'probs':template3.copy(), 'entropies':template2.copy()})
     
    def timeslice(self):
        for message in self.raw:
            sender = message[0]
            recipient = message[1]
            ts = max(ceil((message[2] - self.min_time)/self.timeslice_size) -1, 0)
            if len(message) == 4:
                val = message[3]
            else:
                val = 1
            try:
                self.network['msg_vals'][ts] += val
            except:
                print(len(self.network['msg_vals']), ts)
            
            for n in self.nodes:
                if n['id'] == sender:
                    n['msg_sent'][ts][0] += val
                    if recipient in n['msg_sent'][ts][1]:
                        n['msg_sent'][ts][1][recipient] += val
                    else:
                        n['msg_sent'][ts][1][recipient] = val
                if n['id'] == recipient:
                    n['msg_rcvd'][ts][0] += val
                    if sender in n['msg_rcvd'][ts][1]:
                        n['msg_rcvd'][ts][1][sender] += val
                    else:
                        n['msg_rcvd'][ts][1][sender] = val
    
    def calculate_probs(self):
        for node in self.nodes:
            for ts in range(len(node['msg_sent'])):
                if ts == 0:
                    continue
                for key in node['msg_sent'][ts][1].keys():
                    node_val = node['msg_sent'][ts][1][key]
                    total_val = node['msg_sent'][ts][0]
                    last_probs = node['probs'][ts - 1][key]
                    node['probs'][ts][key] = self.probabilities(node_val, total_val, self.num_nodes, last_probs)
    
    def calculate_entropies(self):
        for node in self.nodes:
            for i in range(len(node['probs'])):
                node['entropies'][i] = self.entropy(node['probs'][i])
                self.network['entropies'][i] += node['entropies'][i]
                
    def display_entropy(self, nodes=[], start=None, stop=None):
        fig, ax = plt.subplots()
        start_ts = 0
        if start == None or stop == None:
            s = slice(None)
        else:
            start_ts = floor(start/self.timeslice_size)
            s = slice(start_ts, floor(stop/self.timeslice_size))
        if nodes == []:
            y_axis = self.network['entropies'][s]
            label = 'Network'
        else:
            y_axis = [0 for x in range(self.num_slices)]
            label='Limited Nodes'
            
            for node in nodes:
                for i in range(len(self.network['entropies'][s])):
                    y_axis[i] += node['entropies'][i + start_ts]
        x_axis = range(0, len(y_axis))
        ax.plot(x_axis, y_axis, label="Limited Nodes")

        plt.show()
    
    def display_graph(self, timeslice):
        n = net.Network(notebook=True)
        node_ids = [self.nodes[i]['id'] for i in range(len(self.nodes))]
        n.add_nodes(node_ids)
        for i in range(len(node_ids)):
            node = self.nodes[i]
            for key in node['probs'][timeslice].keys():
                n.add_edge(node_ids[i], key, length=60/node['probs'][timeslice][key], value=node['probs'][timeslice][key]) 
        n.show_buttons()
        return n

# %%
class Relmeasure_test:
    def __init__(self):
        data = [
            ['a', 'b', 0],
            ['a', 'b', 100],
            ['b', 'c', 200],
            ['b', 'a', 1100],
            ['c', 'b', 1200],
            ['a', 'b', 1250],
            ['a', 'b', 1500],
            ['b', 'a', 2100],
            ['c', 'd', 2200],
            ['d', 'a', 2300],
            ['c', 'b', 2400],
            ['d', 'a', 2500]
        ]
        self.r = Relmeasure(500, 0.3, data)

        
    def test_entropy(self):
        print("")
        print("__Entropy Test__")
        self.__init__()
        print(self.r.entropy({'a':.1, 'b':.1, 'c':.3, 'd':.2, 'e':.1, 'f':.1, 'h':0, 'i':.1}) == 1.8343719702816235)
    
    def test_probabilities(self):
        print("")
        print("__Probabilities Test__")
        self.__init__()
        print(self.r.probabilities(5, 7, 10, .3) == 0.35428571428571426)
    
    def test_init_nodes(self):
        print("")
        print("__Node Init Test__")
        self.__init__()
        self.r.init_nodes()
        print(self.r.num_nodes == 4)
        print(self.r.nodes[0]['msg_sent'][0][0] == 0)
        print(self.r.nodes[0]['msg_sent'][0][1] == {'a': 0, 'b': 0, 'c': 0, 'd': 0})
        print(len(self.r.nodes[0]['msg_sent']) == 5)
        print(self.r.nodes[0]['probs'][0]['a'] == .25)
        print(len(self.r.network['msg_vals']) == 5) 
        print(len(self.r.network['entropies']) == 5)
    
    def test_timeslice(self):
        print("")
        print("_Timeslice Test_")
        self.__init__()
        self.r.init_nodes()
        self.r.timeslice()
        print(self.r.nodes[0]['msg_sent'][0][0] == 6)
        print(self.r.network['msg_vals'][0] == 3)
    
    def test_calc_probs(self):
        print("")
        print("_Probabilities Calculation Test_")
        self.__init__()
        self.r.init_nodes()
        self.r.timeslice()
        self.r.calculate_probs()
        print(self.r.nodes[0]['probs'][3]['a'] == 0.253125)
        
    def test_calc_entropies(self):
        print("")
        print("_Entropies Calculation Test_")
        self.__init__()
        self.r.init_nodes()
        self.r.timeslice()
        self.r.calculate_probs()
        self.r.calculate_entropies()
        print(self.r.nodes[0]['entropies'][4] == 1.3642676316754974)
        print(self.r.network['entropies'][4] == 5.457070526701989)
    
    def tests(self):
        self.test_entropy()
        self.test_probabilities()
        self.test_init_nodes()
        self.test_timeslice()
        self.test_calc_probs()
        self.test_calc_entropies()
        self.r.display_entropy([self.r.nodes[1], self.r.nodes[2]], 0, 5500)
        self.r.display_graph(2)

# %%
r = Relmeasure_test()
r.tests()
# Out:
# __Entropy Test__
# False
#
# __Probabilities Test__
# True
#
# __Node Init Test__
# True
# True
# False
# False
# True
# False
# False
#
# _Timeslice Test_
# True
# True
#
# _Probabilities Calculation Test_
# False
#
# _Entropies Calculation Test_
# False
# False
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# <ipython-input-10-d720bd60f9db> in <module>
#       1 r = Relmeasure_test()
# ----> 2 r.tests()
#
# <ipython-input-9-2442750aa4e8> in tests(self)
#      79         self.test_calc_probs()
#      80         self.test_calc_entropies()
# ---> 81         self.r.display_entropy([self.r.nodes[1], self.r.nodes[2]], 0, 5500)
#      82         self.r.display_graph(2)
#
# <ipython-input-8-d1e116c1f4c8> in display_entropy(self, nodes, start, stop)
#     130             for node in nodes:
#     131                 for i in range(len(self.network['entropies'][s])):
# --> 132                     x_axis[i] += node['entropies'][i + start_ts]
#     133         x_axis = range(0, len(y_axis))
#     134         ax.plot(x_axis, y_axis, label="Limited Nodes")
#
# UnboundLocalError: local variable 'x_axis' referenced before assignment
# /Users/davidjay/miniforge-pypy3/lib_pypy/_functools.py:80: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "orientation" which is no longer supported as of 3.3 and will become an error two minor releases later
#   return self._func(*(self._args + fargs), **fkeywords)

# %% [markdown]
# ## Now to import from the Enron dataset....

# %%
import os
import re
import datetime
notebook_path = os.path.abspath("RML Package.ipynb")

messages = []
directories = os.listdir(os.path.join(os.path.dirname(notebook_path), "maildir/"))
for directory in directories:
    try:
        files = os.listdir(os.path.join(os.path.dirname(notebook_path), "maildir/", directory, 'sent'))
    except:
        print('No sent folder')
        continue
    for filename in files:
        filepath = os.path.join(os.path.dirname(notebook_path), "maildir/", directory, 'sent', filename)
        file = open(filepath)
        try:
            em = ' '.join(file.readlines())
        except:
            print('Unicode error')
        try:
            to_addrs = re.findall("[^-]To: ([^/\n]+)", em)[0].split(', ')
        except:
            print('No to field')
            continue
        from_addr = re.findall("[^-]From: ([^/\n]+)", em)[0]
        date_text = re.findall("Date: ([^/\n]+)", em)[0]
        # For some reason the python library won't support this non-zero-padded format, so add a zero
        if re.search(', [1-9]{1} ', date_text):
            date_text = date_text[:5] + '0' + date_text[5:]
        date_time_obj = datetime.datetime.strptime(date_text, '%a, %d %b %Y %H:%M:%S %z (%Z)')
        date_ts = date_time_obj.timestamp()
        for to_addr in to_addrs:
            messages.append([from_addr, to_addr, date_ts])
        file.close()

print('Done!')
# Out:
# No to field
# No sent folder
# No to field
# No to field
# No to field
# No to field
# No to field
# No sent folder
# No to field
# No sent folder
# No sent folder
# No sent folder
# No to field
# No sent folder
# No to field
# No sent folder
# No sent folder
# No to field
# No to field
# No to field
# No to field
# No to field
# No to field
# No to field
# No to field
# No to field
# No to field
# No to field
# No to field
# No to field
# No to field
# No sent folder
# No to field
# No to field
# No to field
# No to field
# No to field
# No to field
# No sent folder
# No sent folder
# No sent folder
# No sent folder
# No sent folder
# No sent folder
# No sent folder
# No to field
# No sent folder
# No sent folder
# No to field
# No to field
# No sent folder
# No to field
# No sent folder
# No to field
# No to field
# No sent folder
# No to field
# No to field
# No to field
# No to field
# No to field
# No to field
# No to field
# No to field
# No to field
# No to field
# No to field
# No to field
# No to field
# No sent folder
# No sent folder
# No sent folder
# No to field
# No to field
# No to field
# No to field
# No sent folder
# No sent folder
# No sent folder
# No sent folder
# No sent folder
# No sent folder
# No sent folder
# No sent folder
# No sent folder
# No sent folder
# No sent folder
# No sent folder
# No to field
# No to field
# No to field
# No to field
# No to field
# No to field
# No to field
# No to field
# No to field
# No to field
# No sent folder
# No sent folder
# No to field
# No to field
# No to field
# No to field
# No to field
# No to field
# No to field
# No to field
# No to field
# No to field
# No to field
# No to field
# No to field
# No to field
# No to field
# No to field
# No to field
# No to field
# No to field
# No to field
# No to field
# No sent folder
# No to field
# No to field
# No to field
# No to field
# No to field
# No to field
# No to field
# No to field
# No to field
# No to field
# No to field
# No to field
# No to field
# No sent folder
# No sent folder
# No sent folder
# No to field
# No to field
# No sent folder
# No to field
# No to field
# No to field
# No to field
# No to field
# No to field
# No to field
# No to field
# No to field
# No to field
# No to field
# No to field
# No to field
# No sent folder
# Unicode error
# Unicode error
# No sent folder
# No sent folder
# No sent folder
# No sent folder
# No sent folder
# No sent folder
# No sent folder
# No to field
# No to field
# No to field
# No to field
# No sent folder
# No sent folder
# No to field
# No to field
# No to field
# No sent folder
# No sent folder
# No to field
# No sent folder
# No sent folder
# No sent folder
# No sent folder
# No to field
# No sent folder
# No sent folder
# No sent folder
# Done!

# %%
rm = Relmeasure(86400,.2, messages)

# %%
messages[-1]
# Out:
# ['tom.nemila@enron.com', 'mark.fisher@enron.com', 1026462660.0]

# %%
rm.init_nodes()

# %%
len(rm.nodes)
# Out:
# 7815

# %%
rm.timeslice()

# %%
rm.calculate_probs()
# Out:
# marc.r.cutler@bankamerica.com
# mark.taylor@enron.com
# shari.stack@enron.com
# yao.apasu@enron.com
# paul.simons@enron.com
# mtaylor587@aol.com
# justin.boyd@enron.com
# tana.jones@enron.com
# per.sekse@enron.com
# brent.hendry@enron.com
# michelle.cash@enron.com
# Mark - ECT Legal Taylor@ECT
# anita.fam@enron.com
# heather.mitchell@enron.com
# marie.heard@enron.com
# cynthia.sandherr@enron.com
# darlene.forsyth@enron.com
# richard.sanders@enron.com
# alan.aronowitz@enron.com
# scott.sefton@enron.com
# janet.dobernecker@enron.com
# martin.rosell@enron.com
# mzeleanor@juno.com
# tbockius@aol.com
# sara.shackleton@enron.com
#
# susan.flynn@enron.com
# kay.young@enron.com
# janelle.scheuer@enron.com
# fred.lagrasta@enron.com
# george.gilbert@enron.com
# mkopinski@prodigy.net
# sheri.cromwell@enron.com
# jennifer.fraser@enron.com
# jeffrey.hodge@enron.com
# jenny.helton@enron.com
# asmythe@isda.org
# jennifer.sabine@enron.com
# carol.clair@enron.com
# peter.keohane@enron.com
# James Ledlow@ECT
# Michael Parker@ECT
# David
# hessacres@sprintmail.com
# texas_gamma@hotmail.com
# rlehmann@yahoo.com
# jjcardiff@duke-energy.com
# mpierce446@aol.com
# chali.zulu@enron.com
# 8887107934@pagenetmessage.net
# eromero@hou.projectconsulting.com
# kyona@wanadoo.fr
# aklodow@alleghaneyenergy.com
# jpaul@carrfut.com
# aklodow@alleghaenyenergy.com
# djack@keyad.com
# mreuter@kslaw.com
# margaret.doucette@enron.com
# radack@justex.net
# aklodow@alleghenyenergy.com
# kyle.kettler@enron.com
# pcorey@brfg.com
# dbogan@stam.rc.com
# gay.mayeux@enron.com
# team.flagstaff-sta3@enron.com
# team.flagstaff@enron.com
# stephenc@edfman.com
# nicole.russell@mirant.com
# adambob@stat.rice.edu
# mboyd@kpmg.com
# kaplan@iepa.com
# geshay@pplweb.com
# fossum4@home.com
# norm.ruiz@enron.com
# dan.pribble@enron.com
# steve.klimesh@enron.com
# sharon.solon@enron.com
# gary.fuller@enron.com
# mike.riedel@enron.com
# 8774892073@pagenetmessage.net
# gthorse@keyad.com
# mmmarcantel@equva.com
# ld.stephens@enron.com
# david.morris@lehman.com
# kevin_rollins@dell.com
# heather.dunton@enron.com
# samantha.law@enron.com
# lake@argolink.net
# byron.rance@enron.com
# ceicher@lgc.com
# leonsavvas@cs.com
# webbb@dsmo.com
# knorvell@newenergy.com
# johnodam@goforthlewis.com
# israel.estrada@enron.com
# jeremy.metz@verizon.com
# matilda.machado@enron.com
# hendrix2@alumni.auburn.edu
# rami@forestweb.com
# kathy.mcmahon@enron.com
# akim@m-g.com
# pam.losefsky@bus.utexas.edu
# dedeutsch@duke-energy.com
# thackett@ensr.com
# bob.stevens@enron.com
# pamela.lesh@enron.com
# geoff.gray@banking.senate.gov
# awu@quinnemanuel.com
# mdelarosa@cleonline.com
# norman.w.fuchs@williams.com
# hattie.golden@williams.com
# dalton.hogan@enron.com
# kmartinec@houston.rr.com
# karen.o'day@enron.com
# mkerbow@pcenergy.com
# denm90@cc--exs02.prod.entergy.com
# jdecker@entergy.com
# cbaumli@hearme.com
# marshall.brown@robertwalters.com
# huertav@ops.org
# ayueh@hotmail.com
# daniel.garcia@msdw.com
# mcbride@fms2000.com
# margueritekahn@paulhastings.com
# michael.l.matthews@rssmb.com
# bdonaldson@duke-energy.com
# tech_786@yahoo.com
# paulette.brunson@bakerbotts.com
# aparna.rajaram@enron.com
# hillh@stanford.edu
# john@cruiselife.com
# subroto.roy@riskmetrics.com
# Michelle Robichaux
# kbaird@firstrate.com
# dcarmany@hotmail.com
# news@newsworld.co.uk
# bennis@txoga.org
# jcogan@kslaw.com
# mdansel@westvaco.com
# marina.ng@enron.com
# patrick.frnka@enron.com
# dpalmer@kctera.net
# cindyv@lakeaustinspa.com
# bshaughn@lehman.com
# ssmgranmayeh@msn.com
# gnemec@houston.rr.com
# kb@quinnemanuel.com
# pam.boxx@enron.com
# lgeorge@ccj-law.com
# ashill@potashcorp.com
# 8887107935@pagenetmessage.net
# gpack@anz.com
# peter.bennett@enron.com
# okpala.maria@epamail.epa.gov
# tjbutler@enron.com
# tj.butler@enron.com
# john.march@rolls-royceesi.com
# jjankows@kcc.com
# esmeralda.gonzalez@enron.com
# jmccormack@sternstewart.com
# ahl_34@yahoo.com
# ehvaughan@vnsm.com
# lan.comnes@enron.com
# rakesh.bharati@enron.com
# chicagosailers@msn.com
# jayant.krishnaswamy@enron.com
# catherine.mckalip-thompson@enron.com
# mhain@iso-ne.com
# roger.sumlin@enron.com
# dchristo2@attglobal.net
# natalie.wells@enron.com
# michelle_lee37@hotmail.com
# conway77@hotmail.com
# aculver@houston.org
# nate.blackburn@enron.com
# justin.o'malley@enron.com
# michael_kleiner@gulf.ca
# suzanneadams@att.net
# mrgelnett@nyseg.com
# jess.hewitt@enron.com
# mlenhart@houston.rr.com
# wmmontjoy@brunini.com
# robyn.zivic@enron.com
# jsmith@powellclinch.com
# dmorgan@enlineenergy.com
# hweg@pgwlaw.com
# bryant.frihart@enron.com
# alliancetosaveenergy@ase.org
# priest@yazoopsc.org
# mcarroway@watervallery.net
# drhunt@watervalley.net
# mcarroway@watervalley.net
# ohi_supporters@operationhope.org
# pmurphy@swbanktx.com
# noveena.mathew-joy@enron.com
# mmarkey@ftenergy.com
# denisjr@ev1.net
# jamie.wachel@enron.com
# dennisjr@ev1.net
# finn@spectronenergy.com
# tjones@dom.com
# kmargolis@blairpc.com
# christopher.hill@chase.com
# kfleuriot@hou.projectconsulting.com
# ken.curry@enron.com
# vanessa.bob@enron.com
# mark.c.austin@us.andersen.com
# bodilys@darden.virginia.edu
# steven.bailey@enron.com
# jennifer.mendez@enron.com
# wmonjoy@brunini.com
# asorelle@h-s.com
# samon_corinne@jporgan.com
# ilene.erskine@enron.com
# rab@beggslane.com
# randy.g.kruger.jr@us.arthurandersen.com
# julie.benn@tmp.com
# jward@kpcb.com
# parking.transportation@enron.com
# chris.lackey@enron.com
# carlyle@bu.edu
# christopher_knudsen@hotmail.com
# angie.hueca@enron.com
# oscar.cedeno@enron.com
# ramon.pizarro@enron.com
# david.shields@enron.com
# kendra.lee@enron.com
# martin.bucknell@enron.com
# scsatkfa@caprock.net
# brett.pate@enron.com
# amy.smith@enron.com
# scfatkfa@caprock.net
# julie.cohn@ecot.rice.edu
# rrussin@natsource.com
# jpuzio@nui.com
# pchymiy@nui.com
# mgentry@hwallp.com
# theresa.zucha@enron.com
# bill.breslin@insource.com
# david.woodstrom@enron.com
# jons@amerexyenergy.com
# payne@bipac.org
# jennifer.m.erich@exxonmobil.com
# gailg@morgangroup.com
# dave.kapavik@verizon.com
# sales@cortlandtwines.com
# neil.kenley@enron.com
# stanmarek@marekbros.com
# david.jones@enron.com
# teigland@sullcrom.com
# angelo.miroballi@enron.com
# gruyinc@flash.net
# amy.cavazos@enron.com
# robr@starsupply.com
# paugustini@cera.com
# rvincens@deltapower.com
# gregorylang@paulhastings.com
# rvicens@deltapower.com
# lcs1110@hotmail.com
# avramsiegel@hotmail.com
# avramsiegel@yahoo.com
# cathy@intelligencepress.com

# %%
rm.calculate_entropies()

# %%
rm.display_entropy()

# %%
rm.display_graph(100).show('test.html')
# Out:
#         <iframe
#             width="500px"
#             height="500px"
#             src="test.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
